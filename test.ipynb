# %%
import pandas as pd
from random import randint

from BlockChain import BlockChain

# %%
bc = BlockChain('dummy', randint(0,100))

table = {bc.hash(): bc.get()}
for i in range(1000):
    table.update({bc.hash(): bc.generate(randint(0,10000), randint(0,100))})

# %%
df = pd.DataFrame(table).T
df
# Out:
#                                                                                               prehash  \
# bf150eccc0c3daa02ec66f99d17bba7bebc167446c1130f...                                                  0
# 8eba4aee8f475cfd49b216e435c683703c109e16fc09239...  bf150eccc0c3daa02ec66f99d17bba7bebc167446c1130...
# 81b7199e129dd1e6af60105a02e89d5e5402926b306f201...  8eba4aee8f475cfd49b216e435c683703c109e16fc0923...
# 95d7032030ed02dfc6d1ce27b2c9f57739a350cb34120d6...  81b7199e129dd1e6af60105a02e89d5e5402926b306f20...
# 802b9e2de3f75eec94dd363d0261b3d71441cb9858590c2...  95d7032030ed02dfc6d1ce27b2c9f57739a350cb34120d...
# ...                                                                                               ...
# d19d46e72b4917a2994da11178b879f5f8f5e3d4e6010fd...  ebb9f269f5cad75db59a661745daa89fceb35a4facde16...
# 42d306f60f00bb69dc02ff03e06b1ad65644f2afde4f9c0...  d19d46e72b4917a2994da11178b879f5f8f5e3d4e6010f...
# ...
